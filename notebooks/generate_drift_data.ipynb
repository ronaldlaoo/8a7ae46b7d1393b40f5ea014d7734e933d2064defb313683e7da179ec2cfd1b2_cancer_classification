# %%
import pandas as pd
import numpy as np
import os
import sys
from pathlib import Path

# %%
def get_root():
   root = next(p for p in [Path.cwd(), *Path.cwd().parents] if (p / ".git").exists())
   return root

def preprocess_data():
   logger.info("Starting drift data generation")
   root = get_root()
   data_path = root / "data" / "cancer_data.csv"
   data = pd.read_csv(data_path)

# %%
root = get_root()
data_path = root / "data" / "cancer_data.csv"
data = pd.read_csv(data_path) 

# Select numeric columns
numeric_cols = data.select_dtypes(include=[np.number]).columns.tolist()
num_data = data[numeric_cols]

# Add gaussian noise to numeric columns
noise = np.random.normal(0, 0.1, num_data.shape)
